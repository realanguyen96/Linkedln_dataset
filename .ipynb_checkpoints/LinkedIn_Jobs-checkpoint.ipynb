# %% [markdown]
# # CPSC 4810 TEAM PROJECT
# ### Member:
# - An Nguyen
# - Andy Nguyen
# - Dawn Dang
# - Huan Le Van

# %% [markdown]
# # TABLE OF CONTENTS
# 1. [PROJECT DESCRIPTION](#prob)
# 2. [BACKGROUND RESEARCH](#research)
# 3. [THE DATA](#data)
#     1. [Supplemental Data](#supdata)
# 4. [READ IN THE DATA](#reading)
#     1. Reading .csv files
#     2. Reading .txt files
# 5. [DATA TRANSFORMATION](#trans)
# 6. DATA ANALYSIS
#     1. Jobs postings
#     2. Company details

# %% [markdown]
# ## PROJECT DESCRIPTION<a id='prob'></a>
#
# Our project focuses on analyzing job postings on LinkedIn in the USA last year, using a combination of datasets to ensure we cover all the necessary information. We prioritize data acquisition, preparation, cleaning, and aggregation to create a top-notch dataset for exploratory data analysis (EDA). Through EDA, we aim to discover important insights into the job market, like popular skills, common job titles, where opportunities are located, and trends in different industries. By providing clear insights, our project aims to help decision-making and improve the job market.

# %% [markdown]
# ## BACKGROUND RESEARCH<a id='research'></a>
#
# Our research centers on analyzing job advertisements on LinkedIn within the United States in 2023. We aim to understand job posting trends, companies' profiles, and job requirements and compensations. Given the complexity of the datasets, we must clean, map, combine, or drop datasets to ensure accuracy.
#
# Key areas of focus include:
#
# - Job Ads Posted on LinkedIn in the US: Examining trends and geographical variations across 50 states.
# - Companies Posting Jobs: Analyzing company profiles, including size and industry.
# - Job Requirements and Compensation: Investigating diverse skill sets and salary structures.
#
# Our analysis acknowledges variability across states and industries, guiding us to consolidate datasets for effective exploration of correlations and patterns.

# %% [markdown]
# ## THE DATA<a id='data'></a>
#
# Every day, LinkedIn serves as a go-to platform for thousands of companies and individuals seeking talent or career opportunities. This dataset offers an extensive collection of over 33,000 job postings spanning two distinct days, months apart. Each job listing is rich in detail, encompassing 27 key attributes such as job title, description, salary, location, application URL, and work arrangements (including remote or contract positions). Additionally, supplemental files provide insights into associated benefits, required skills, and relevant industries. Linked to the majority of job postings are corresponding company profiles, detailed in a separate CSV file, featuring company descriptions, headquarters location, employee count, and follower metrics.
# Our main datasets:
# - companies.csv - Details about hiring companies
# - job_postings.csv - Details about the jobs

# %% [markdown]
# ## SUPPLEMENT DATA<a id='supdata'></a>
#
# Our project also utilise supplemental files from the same source; that offer enriched insights into the job market. These additional datasets provide valuable information on benefits, skills, industries, and company profiles associated with each job posting. By exploring these supplementary datasets, users gain deeper insights into job market dynamics, enabling informed decision-making and strategic planning in talent acquisition and employment.
#
# Supplement datasets:
# - **company_industries.csv** : Details on hiring compannies' registered industry names including company IDs.
# - **industries.csv** and **jobs_industries.csv**: Lists of industry IDs, matching job IDs, and industry names.
# - **company_specialities.csv**: Details on hiring companies special field.
# - **employee_counts.csv**: Provide information about hiring companies' number of current employees, its followers and well as the time said data were collected.
# - **job_skills.csv** and **skills.csv**: Lists of the key required skills for each job, along with matching job IDs and skill abbreviations.
# - **benefit.csv**: contains lists of benefits offered, each matched with corresponding job IDs.
# - **Salaries.csv**: provides information on the compensation range for each job ID, including pay period, currency, and compensation type.
#
# - **abbr-name.json**: external data for list of states, using to get state name from address

# %% [markdown]
# <img align=left src="images/LinkedIn_Jobs.drawio.png" height="600" width="800">

# %% [markdown]
# ## READING DATA<a id='reading'></a>

# %%
#Import library
import pandas as pd
import numpy as np

# %% [markdown]
# #### Jobs_postings

# %%
#load data
jobs_posting = pd.read_csv('./data/job_postings.csv')
jobs_posting.head(5)
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#    max_salary  med_salary  min_salary pay_period formatted_work_type  \
# 0         NaN     5250.00         NaN    MONTHLY           Full-time
# 1         NaN         NaN         NaN        NaN           Full-time
# 2         NaN         NaN         NaN        NaN           Full-time
# 3         NaN       22.27         NaN     HOURLY           Full-time
# 4    275834.0         NaN    205956.0     YEARLY           Full-time
#
#            location  applies  ...  closed_time  formatted_experience_level  \
# 0  Little River, SC      NaN  ...          NaN                 Entry level
# 1    Beaver Dam, WI      NaN  ...          NaN                         NaN
# 2      Bessemer, AL      NaN  ...          NaN                         NaN
# 3   Aliso Viejo, CA      NaN  ...          NaN                 Entry level
# 4     United States      NaN  ...          NaN            Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.700000e+12
# 1                                                NaN  1.700000e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.700000e+12
# 3                                                NaN  1.700000e+12
# 4                                                NaN  1.700000e+12
#
#              posting_domain sponsored  work_type  currency compensation_type  \
# 0  careers-demant.icims.com         0  FULL_TIME       USD       BASE_SALARY
# 1       www.click2apply.net         0  FULL_TIME       NaN               NaN
# 2       www.click2apply.net         0  FULL_TIME       NaN               NaN
# 3           jobs.apploi.com         0  FULL_TIME       USD       BASE_SALARY
# 4         careers.iherb.com         0  FULL_TIME       USD       BASE_SALARY
#
#       scraped
# 0  1699138101
# 1  1699085420
# 2  1699085644
# 3  1699087461
# 4  1699085346
#
# [5 rows x 27 columns]

# %% [markdown]
# #### company_detail

# %%
df_comp = pd.read_csv('./data/company_details/companies.csv')
df_comp.head(5)
# Out:
#    company_id                        name  \
# 0        1009                         IBM
# 1        1016               GE HealthCare
# 2        1021                    GE Power
# 3        1025  Hewlett Packard Enterprise
# 4        1028                      Oracle
#
#                                          description  company_size  state  \
# 0  At IBM, we do more than work. We create. We cr...           7.0     NY
# 1  Every day millions of people feel the impact o...           7.0      0
# 2  GE Power, part of GE Vernova, is a world energ...           7.0     NY
# 3  Official LinkedIn of Hewlett Packard Enterpris...           7.0  Texas
# 4  We’re a cloud technology company that provides...           7.0  Texas
#
#   country              city zip_code                                address  \
# 0      US  Armonk, New York    10504  International Business Machines Corp.
# 1      US           Chicago        0                                      -
# 2      US       Schenectady    12345                           1 River Road
# 3      US           Houston    77389            1701 E Mossy Oaks Rd Spring
# 4      US            Austin    78741                        2300 Oracle Way
#
#                                                  url
# 0               https://www.linkedin.com/company/ibm
# 1      https://www.linkedin.com/company/gehealthcare
# 2           https://www.linkedin.com/company/gepower
# 3  https://www.linkedin.com/company/hewlett-packa...
# 4            https://www.linkedin.com/company/oracle

# %% [markdown]
# ## DATA TRANSFORMATION<a id='trans'></a>

# %% [markdown]
# ### Mapping company sizes
# We generate a mapping file to correlate company size levels (1-7) with real company sizes on LinkedIn, aiming to explore how company size influences offered skills and salaries in job postings.

# %%
comp_level = {
    'Level': [7, 6, 5, 4, 3, 2, 1],
    'Company size': ['10,001 +', '5001-10,000', '1001-5000', '501-1000', '201-500', '51-200', 'Under 50']
}

df_comp_level = pd.DataFrame(comp_level)
df_comp_level
# Out:
#    Level Company size
# 0      7     10,001 +
# 1      6  5001-10,000
# 2      5    1001-5000
# 3      4     501-1000
# 4      3      201-500
# 5      2       51-200
# 6      1     Under 50

# %%
df_comp_merged = pd.merge(df_comp_level, df_comp, left_on='Level', right_on='company_size', how='inner')
df_comp_merged.head(5)
# Out:
#    Level Company size  company_id                        name  \
# 0      7     10,001 +        1009                         IBM
# 1      7     10,001 +        1016               GE HealthCare
# 2      7     10,001 +        1021                    GE Power
# 3      7     10,001 +        1025  Hewlett Packard Enterprise
# 4      7     10,001 +        1028                      Oracle
#
#                                          description  company_size  state  \
# 0  At IBM, we do more than work. We create. We cr...           7.0     NY
# 1  Every day millions of people feel the impact o...           7.0      0
# 2  GE Power, part of GE Vernova, is a world energ...           7.0     NY
# 3  Official LinkedIn of Hewlett Packard Enterpris...           7.0  Texas
# 4  We’re a cloud technology company that provides...           7.0  Texas
#
#   country              city zip_code                                address  \
# 0      US  Armonk, New York    10504  International Business Machines Corp.
# 1      US           Chicago        0                                      -
# 2      US       Schenectady    12345                           1 River Road
# 3      US           Houston    77389            1701 E Mossy Oaks Rd Spring
# 4      US            Austin    78741                        2300 Oracle Way
#
#                                                  url
# 0               https://www.linkedin.com/company/ibm
# 1      https://www.linkedin.com/company/gehealthcare
# 2           https://www.linkedin.com/company/gepower
# 3  https://www.linkedin.com/company/hewlett-packa...
# 4            https://www.linkedin.com/company/oracle

# %% [markdown]
# ### Convert number to datetime format
# Data store the date and time the posting was posted, expired but in epoch format so we need to convert to readable date time format

# %%
jobs_posting['new_original_listed_time'] = pd.to_datetime(jobs_posting['original_listed_time'], unit='ms')
jobs_posting['new_closed_time'] = pd.to_datetime(jobs_posting['closed_time'], unit='ms')
jobs_posting['new_listed_time'] = pd.to_datetime(jobs_posting['listed_time'], unit='ms')

# %%
jobs_posting[['closed_time','listed_time','new_original_listed_time','new_closed_time','new_listed_time']]
# Out:
#        closed_time   listed_time new_original_listed_time new_closed_time  \
# 0              NaN  1.700000e+12      2023-11-14 22:13:20             NaT
# 1              NaN  1.700000e+12      2023-11-14 22:13:20             NaT
# 2              NaN  1.700000e+12      2023-11-14 22:13:20             NaT
# 3              NaN  1.700000e+12      2023-11-14 22:13:20             NaT
# 4              NaN  1.700000e+12      2023-11-14 22:13:20             NaT
# ...            ...           ...                      ...             ...
# 33241          NaN  1.690000e+12      2023-07-22 04:26:40             NaT
# 33242          NaN  1.700000e+12      2023-11-14 22:13:20             NaT
# 33243          NaN  1.700000e+12      2023-11-14 22:13:20             NaT
# 33244          NaN  1.690000e+12      2023-07-22 04:26:40             NaT
# 33245          NaN  1.700000e+12      2023-11-14 22:13:20             NaT
#
#           new_listed_time
# 0     2023-11-14 22:13:20
# 1     2023-11-14 22:13:20
# 2     2023-11-14 22:13:20
# 3     2023-11-14 22:13:20
# 4     2023-11-14 22:13:20
# ...                   ...
# 33241 2023-07-22 04:26:40
# 33242 2023-11-14 22:13:20
# 33243 2023-11-14 22:13:20
# 33244 2023-07-22 04:26:40
# 33245 2023-11-14 22:13:20
#
# [33246 rows x 5 columns]

# %% [markdown]
# ### Calculate yearly average salary

# %% [markdown]
# The salary data in the raw file is in different format (Yearly, Monthly, Hourly, Weekly ...)

# %%
jobs_posting['pay_period'].unique()
# Out:
# array(['MONTHLY', nan, 'HOURLY', 'YEARLY', 'WEEKLY', 'ONCE'], dtype=object)

# %% [markdown]
# We have to transform the salary to a single format (__Yearly__) to do the related analysis

# %% [markdown]
# avarage = medium salary or = (max + min) /2

# %%
# Fill NaN values in 'med_salary' with the average of 'max_salary' and 'min_salary'
jobs_posting['avg_salary'] = jobs_posting['med_salary'].fillna((jobs_posting['max_salary'] + jobs_posting['min_salary']) / 2)

# Change all salary to yearly salary unit
jobs_posting['yearly_avg_salary'] = jobs_posting['avg_salary']
multiplier_map = {'YEARLY': 1,
                  'HOURLY': 40 * 52.2,
                  'MONTHLY': 12,
                  'WEEKLY': 52.2,
                  'ONCE': 1}
jobs_posting['yearly_avg_salary'] *= jobs_posting['pay_period'].map(multiplier_map)
jobs_posting.head(5)
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#    max_salary  med_salary  min_salary pay_period formatted_work_type  \
# 0         NaN     5250.00         NaN    MONTHLY           Full-time
# 1         NaN         NaN         NaN        NaN           Full-time
# 2         NaN         NaN         NaN        NaN           Full-time
# 3         NaN       22.27         NaN     HOURLY           Full-time
# 4    275834.0         NaN    205956.0     YEARLY           Full-time
#
#            location  applies  ...  sponsored  work_type  currency  \
# 0  Little River, SC      NaN  ...          0  FULL_TIME       USD
# 1    Beaver Dam, WI      NaN  ...          0  FULL_TIME       NaN
# 2      Bessemer, AL      NaN  ...          0  FULL_TIME       NaN
# 3   Aliso Viejo, CA      NaN  ...          0  FULL_TIME       USD
# 4     United States      NaN  ...          0  FULL_TIME       USD
#
#   compensation_type     scraped new_original_listed_time  new_closed_time  \
# 0       BASE_SALARY  1699138101      2023-11-14 22:13:20              NaT
# 1               NaN  1699085420      2023-11-14 22:13:20              NaT
# 2               NaN  1699085644      2023-11-14 22:13:20              NaT
# 3       BASE_SALARY  1699087461      2023-11-14 22:13:20              NaT
# 4       BASE_SALARY  1699085346      2023-11-14 22:13:20              NaT
#
#       new_listed_time avg_salary yearly_avg_salary
# 0 2023-11-14 22:13:20    5250.00          63000.00
# 1 2023-11-14 22:13:20        NaN               NaN
# 2 2023-11-14 22:13:20        NaN               NaN
# 3 2023-11-14 22:13:20      22.27          46499.76
# 4 2023-11-14 22:13:20  240895.00         240895.00
#
# [5 rows x 32 columns]

# %% [markdown]
# For the jobs with NA salary, we are going to fill with the mean values of similar job (same industry, work_type, experience_level)

# %%
jobs_posting[jobs_posting['yearly_avg_salary'].isnull()]
# Out:
#            job_id  company_id  \
# 1      3757940025   2192142.0
# 2      3757938019    474443.0
# 5      3757937037     13727.0
# 6      3757937004  10515052.0
# 7      3757936167      2915.0
# ...           ...         ...
# 33239   218881389         NaN
# 33240   133196985   1089558.0
# 33241   133114754  77766802.0
# 33242   108965123         NaN
# 33243   102339515  52132271.0
#
#                                                    title  max_salary  \
# 1      Shipping & Receiving Associate 2nd shift (Beav...         NaN
# 2                                   Manager, Engineering         NaN
# 5                          Territory Manager - New Haven         NaN
# 6                                    Auto Body Techncian         NaN
# 7          ACME D8- Asst Store Director (ASD) Sussex, NJ         NaN
# ...                                                  ...         ...
# 33239                               Accounting Associate         NaN
# 33240                                 Model Risk Auditor         NaN
# 33241                                      Sales Manager         NaN
# 33242                    Office Administrative Assistant         NaN
# 33243                                    Franchise Owner         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN           Full-time
# 5             NaN         NaN        NaN           Full-time
# 6             NaN         NaN        NaN           Full-time
# 7             NaN         NaN        NaN           Full-time
# ...           ...         ...        ...                 ...
# 33239         NaN         NaN        NaN           Full-time
# 33240         NaN         NaN        NaN            Contract
# 33241         NaN         NaN        NaN           Full-time
# 33242         NaN         NaN        NaN           Full-time
# 33243         NaN         NaN        NaN           Full-time
#
#                 location  applies  ...  sponsored  work_type  currency  \
# 1         Beaver Dam, WI      NaN  ...          0  FULL_TIME       NaN
# 2           Bessemer, AL      NaN  ...          0  FULL_TIME       NaN
# 5          United States      NaN  ...          0  FULL_TIME       NaN
# 6      Daytona Beach, FL      NaN  ...          0  FULL_TIME       NaN
# 7             Sussex, NJ      NaN  ...          0  FULL_TIME       NaN
# ...                  ...      ...  ...        ...        ...       ...
# 33239    Bolingbrook, IL      1.0  ...          0  FULL_TIME       NaN
# 33240       New York, NY      1.0  ...          0   CONTRACT       NaN
# 33241  Santa Clarita, CA      NaN  ...          0  FULL_TIME       NaN
# 33242       New York, NY      2.0  ...          0  FULL_TIME       NaN
# 33243     Greater Boston      NaN  ...          0  FULL_TIME       NaN
#
#       compensation_type     scraped new_original_listed_time  \
# 1                   NaN  1699085420      2023-11-14 22:13:20
# 2                   NaN  1699085644      2023-11-14 22:13:20
# 5                   NaN  1699137801      2023-11-14 22:13:20
# 6                   NaN  1699089473      2023-11-14 22:13:20
# 7                   NaN  1699138852      2023-11-14 22:13:20
# ...                 ...         ...                      ...
# 33239               NaN  1699084455      2023-11-14 22:13:20
# 33240               NaN           1      2023-07-22 04:26:40
# 33241               NaN           1      2023-07-22 04:26:40
# 33242               NaN  1699044401      2023-11-14 22:13:20
# 33243               NaN  1699063495      2023-11-14 22:13:20
#
#           new_closed_time     new_listed_time avg_salary yearly_avg_salary
# 1                     NaT 2023-11-14 22:13:20        NaN               NaN
# 2                     NaT 2023-11-14 22:13:20        NaN               NaN
# 5     2023-11-14 22:13:20 2023-11-14 22:13:20        NaN               NaN
# 6                     NaT 2023-11-14 22:13:20        NaN               NaN
# 7                     NaT 2023-11-14 22:13:20        NaN               NaN
# ...                   ...                 ...        ...               ...
# 33239                 NaT 2023-11-14 22:13:20        NaN               NaN
# 33240                 NaT 2023-07-22 04:26:40        NaN               NaN
# 33241                 NaT 2023-07-22 04:26:40        NaN               NaN
# 33242                 NaT 2023-11-14 22:13:20        NaN               NaN
# 33243                 NaT 2023-11-14 22:13:20        NaN               NaN
#
# [19894 rows x 32 columns]

# %% [markdown]
# Get job industries:

# %%
job_industries = pd.read_csv('./data/job_details/job_industries.csv')
industries = pd.read_csv('./data/maps/industries.csv')

# %%
jobs_posting_2 = pd.merge(jobs_posting,job_industries, on = 'job_id', how = 'left')
jobs_posting_2 = pd.merge(jobs_posting_2, industries, on = 'industry_id', how = 'left')
jobs_posting_2.head(5)
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#    max_salary  med_salary  min_salary pay_period formatted_work_type  \
# 0         NaN     5250.00         NaN    MONTHLY           Full-time
# 1         NaN         NaN         NaN        NaN           Full-time
# 2         NaN         NaN         NaN        NaN           Full-time
# 3         NaN       22.27         NaN     HOURLY           Full-time
# 4    275834.0         NaN    205956.0     YEARLY           Full-time
#
#            location  applies  ...  currency  compensation_type     scraped  \
# 0  Little River, SC      NaN  ...       USD        BASE_SALARY  1699138101
# 1    Beaver Dam, WI      NaN  ...       NaN                NaN  1699085420
# 2      Bessemer, AL      NaN  ...       NaN                NaN  1699085644
# 3   Aliso Viejo, CA      NaN  ...       USD        BASE_SALARY  1699087461
# 4     United States      NaN  ...       USD        BASE_SALARY  1699085346
#
#   new_original_listed_time new_closed_time     new_listed_time  avg_salary  \
# 0      2023-11-14 22:13:20             NaT 2023-11-14 22:13:20     5250.00
# 1      2023-11-14 22:13:20             NaT 2023-11-14 22:13:20         NaN
# 2      2023-11-14 22:13:20             NaT 2023-11-14 22:13:20         NaN
# 3      2023-11-14 22:13:20             NaT 2023-11-14 22:13:20       22.27
# 4      2023-11-14 22:13:20             NaT 2023-11-14 22:13:20   240895.00
#
#    yearly_avg_salary industry_id                       industry_name
# 0           63000.00        17.0     Medical Equipment Manufacturing
# 1                NaN       135.0  Industrial Machinery Manufacturing
# 2                NaN       147.0  Automation Machinery Manufacturing
# 3           46499.76       100.0            Non-profit Organizations
# 4          240895.00        27.0                              Retail
#
# [5 rows x 34 columns]

# %%
#fill NA
jobs_posting_2['yearly_avg_salary'] = jobs_posting_2.groupby(['formatted_work_type', 'formatted_experience_level','industry_name'])['yearly_avg_salary'].transform(lambda x: x.fillna(x.mean()))

# If there are still NaN values that couldn't be filled because the entire group had NaN, fill them with the mean of the whole 'yearly_avg_salary' column
#jobs_posting['yearly_avg_salary'].fillna(jobs_posting['yearly_avg_salary'].mean(), inplace=True)

# %%
jobs_posting_2[jobs_posting_2['yearly_avg_salary'].isnull()]
# Out:
#            job_id  company_id  \
# 1      3757940025   2192142.0
# 2      3757938019    474443.0
# 12     3757935384    232541.0
# 15     3757935026  16223627.0
# 22     3757934944  18270206.0
# ...           ...         ...
# 43590   133114754  77766802.0
# 43591   108965123         NaN
# 43592   102339515  52132271.0
# 43593    85008768         NaN
# 43594     3958427    630152.0
#
#                                                    title  max_salary  \
# 1      Shipping & Receiving Associate 2nd shift (Beav...         NaN
# 2                                   Manager, Engineering         NaN
# 12       Power Utility Distribution Designer II (Remote)         NaN
# 15                                    Nurse Practitioner         NaN
# 22                                  Branch Manager Truss         NaN
# ...                                                  ...         ...
# 43590                                      Sales Manager         NaN
# 43591                    Office Administrative Assistant         NaN
# 43592                                    Franchise Owner         NaN
# 43593                           Licensed Insurance Agent     52000.0
# 43594                                   Stylist/ Clorist     80000.0
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN           Full-time
# 12            NaN         NaN        NaN           Full-time
# 15            NaN         NaN        NaN            Contract
# 22            NaN         NaN        NaN           Full-time
# ...           ...         ...        ...                 ...
# 43590         NaN         NaN        NaN           Full-time
# 43591         NaN         NaN        NaN           Full-time
# 43592         NaN         NaN        NaN           Full-time
# 43593         NaN     45760.0     YEARLY           Full-time
# 43594         NaN     35000.0     YEARLY           Full-time
#
#                 location  applies  ...  currency  compensation_type  \
# 1         Beaver Dam, WI      NaN  ...       NaN                NaN
# 2           Bessemer, AL      NaN  ...       NaN                NaN
# 12           Hammond, IN      NaN  ...       NaN                NaN
# 15        Toms River, NJ      NaN  ...       NaN                NaN
# 22         La Grande, OR      NaN  ...       NaN                NaN
# ...                  ...      ...  ...       ...                ...
# 43590  Santa Clarita, CA      NaN  ...       NaN                NaN
# 43591       New York, NY      2.0  ...       NaN                NaN
# 43592     Greater Boston      NaN  ...       NaN                NaN
# 43593          Chico, CA      NaN  ...       USD        BASE_SALARY
# 43594        Chicago, IL      NaN  ...       USD        BASE_SALARY
#
#           scraped new_original_listed_time new_closed_time  \
# 1      1699085420      2023-11-14 22:13:20             NaT
# 2      1699085644      2023-11-14 22:13:20             NaT
# 12     1699086574      2023-11-14 22:13:20             NaT
# 15     1699139453      2023-11-14 22:13:20             NaT
# 22     1699136299      2023-11-14 22:13:20             NaT
# ...           ...                      ...             ...
# 43590           1      2023-07-22 04:26:40             NaT
# 43591  1699044401      2023-11-14 22:13:20             NaT
# 43592  1699063495      2023-11-14 22:13:20             NaT
# 43593           1      2023-07-22 04:26:40             NaT
# 43594  1699057868      2023-11-14 22:13:20             NaT
#
#           new_listed_time  avg_salary  yearly_avg_salary industry_id  \
# 1     2023-11-14 22:13:20         NaN                NaN       135.0
# 2     2023-11-14 22:13:20         NaN                NaN       147.0
# 12    2023-11-14 22:13:20         NaN                NaN      3242.0
# 15    2023-11-14 22:13:20         NaN                NaN        14.0
# 22    2023-11-14 22:13:20         NaN                NaN      1324.0
# ...                   ...         ...                ...         ...
# 43590 2023-07-22 04:26:40         NaN                NaN        92.0
# 43591 2023-11-14 22:13:20         NaN                NaN        19.0
# 43592 2023-11-14 22:13:20         NaN                NaN        91.0
# 43593 2023-07-22 04:26:40     48880.0                NaN        42.0
# 43594 2023-11-14 22:13:20     57500.0                NaN        18.0
#
#                                         industry_name
# 1                  Industrial Machinery Manufacturing
# 2                  Automation Machinery Manufacturing
# 12                               Engineering Services
# 15                          Hospitals and Health Care
# 22     Retail Building Materials and Garden Equipment
# ...                                               ...
# 43590                            Truck Transportation
# 43591                      Retail Apparel and Fashion
# 43592                               Consumer Services
# 43593                                       Insurance
# 43594             Personal Care Product Manufacturing
#
# [12535 rows x 34 columns]

# %% [markdown]
# ### Remove NA row for missing experience level

# %%
jobs_posting.columns.tolist()
# Out:
# ['job_id',
#  'company_id',
#  'title',
#  'max_salary',
#  'med_salary',
#  'min_salary',
#  'pay_period',
#  'formatted_work_type',
#  'location',
#  'applies',
#  'original_listed_time',
#  'remote_allowed',
#  'views',
#  'job_posting_url',
#  'application_url',
#  'application_type',
#  'expiry',
#  'closed_time',
#  'formatted_experience_level',
#  'skills_desc',
#  'listed_time',
#  'posting_domain',
#  'sponsored',
#  'work_type',
#  'currency',
#  'compensation_type',
#  'scraped',
#  'new_original_listed_time',
#  'new_closed_time',
#  'new_listed_time',
#  'avg_salary',
#  'yearly_avg_salary']

# %%
jobs_posting['formatted_experience_level'].value_counts(dropna=False)
# Out:
# formatted_experience_level
# Mid-Senior level    11258
# NaN                  9181
# Entry level          7969
# Associate            2793
# Director             1354
# Internship            387
# Executive             304
# Name: count, dtype: int64

# %%
jobs_posting['formatted_experience_level'].isna().sum()
# Out:
# 9181

# %%
jobs_posting['formatted_experience_level'].notna().sum()
# Out:
# 24065

# %%
jobs_posting = jobs_posting[jobs_posting['formatted_experience_level'].notnull()]
jobs_posting['formatted_experience_level'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Location
#
# The Location column in the dataset include 4 format of infomation:
# - Country (United States)
# - City + Shortname of state (Ex: New York, NY ..)
# - City + State + Country (Ex: St Clair Shores, Michigan, United States ..)
# - Metropolitan Area (Ex: New York City Metropolitan Area ..)
#
# In the scope of this analysis, we just deal with the 2nd & 3rd types, which is to process the state infomation

# %%
jobs_posting.groupby('location').size().reset_index(name = 'counts').sort_values(by = 'counts', ascending=False).head(15)
# Out:
#                              location  counts
# 3629                    United States    1407
# 2512                     New York, NY     561
# 628                       Chicago, IL     391
# 1641                      Houston, TX     322
# 138                       Atlanta, GA     294
# 830                        Dallas, TX     294
# 360                        Boston, MA     252
# 162                        Austin, TX     236
# 2048                  Los Angeles, CA     212
# 3737                   Washington, DC     203
# 599                     Charlotte, NC     201
# 3145                San Francisco, CA     200
# 2814                      Phoenix, AZ     188
# 2511  New York City Metropolitan Area     184
# 3215                      Seattle, WA     177

# %% [markdown]
# External dataset __abbr-name.json__ includes infomation of shortname mapping to name of state

# %%
df_states = pd.read_json('./data/abbr-name.json', orient='index')
df_states.reset_index(inplace=True)
df_states.columns = ['state_short_name', 'state']
df_states.head(5)
# Out:
#   state_short_name       state
# 0               AL     Alabama
# 1               AK      Alaska
# 2               AZ     Arizona
# 3               AR    Arkansas
# 4               CA  California

# %% [markdown]
# Filter list of locations (City, State) from the job_posting dataset:

# %%
df_location  = pd.DataFrame(jobs_posting[(jobs_posting['location'].str.contains(','))]['location'].unique())
df_location.columns  = ['Location']
df_location.head(5)
# Out:
#                Location
# 0      Little River, SC
# 1       Aliso Viejo, CA
# 2     Daytona Beach, FL
# 3            Sussex, NJ
# 4  Texas, United States

# %%
df_location[['city','state','country']] = df_location['Location'].str.split(', ', expand=True)
df_location
# Out:
#                   Location             city          state country
# 0         Little River, SC     Little River             SC    None
# 1          Aliso Viejo, CA      Aliso Viejo             CA    None
# 2        Daytona Beach, FL    Daytona Beach             FL    None
# 3               Sussex, NJ           Sussex             NJ    None
# 4     Texas, United States            Texas  United States    None
# ...                    ...              ...            ...     ...
# 3866   University Park, PA  University Park             PA    None
# 3867      Marshalltown, IA     Marshalltown             IA    None
# 3868    Valley Cottage, NY   Valley Cottage             NY    None
# 3869         De Forest, WI        De Forest             WI    None
# 3870      North Canton, OH     North Canton             OH    None
#
# [3871 rows x 4 columns]

# %% [markdown]
# Now we join with state list (__abbr-name.json__) to get statename

# %%
df_location_merge = pd.merge(df_location, df_states, left_on='state', right_on='state_short_name', how='left')
df_location_merge
# Out:
#                   Location             city        state_x country  \
# 0         Little River, SC     Little River             SC    None
# 1          Aliso Viejo, CA      Aliso Viejo             CA    None
# 2        Daytona Beach, FL    Daytona Beach             FL    None
# 3               Sussex, NJ           Sussex             NJ    None
# 4     Texas, United States            Texas  United States    None
# ...                    ...              ...            ...     ...
# 3866   University Park, PA  University Park             PA    None
# 3867      Marshalltown, IA     Marshalltown             IA    None
# 3868    Valley Cottage, NY   Valley Cottage             NY    None
# 3869         De Forest, WI        De Forest             WI    None
# 3870      North Canton, OH     North Canton             OH    None
#
#      state_short_name         state_y
# 0                  SC  South Carolina
# 1                  CA      California
# 2                  FL         Florida
# 3                  NJ      New Jersey
# 4                 NaN             NaN
# ...               ...             ...
# 3866               PA    Pennsylvania
# 3867               IA            Iowa
# 3868               NY        New York
# 3869               WI       Wisconsin
# 3870               OH            Ohio
#
# [3871 rows x 6 columns]

# %% [markdown]
# However, when filtering the location with column country is not null, we can see that the state_x column is already in full state name. So we just update the state_y colums = state_x columns for these rows

# %%
df_location_merge[df_location_merge['country'].notnull()].head(5)
# Out:
#                                      Location             city     state_x  \
# 5    St Clair Shores, Michigan, United States  St Clair Shores    Michigan
# 155       Wilmington, Delaware, United States       Wilmington    Delaware
# 211           Denver, Colorado, United States           Denver    Colorado
# 233        Fremont, California, United States          Fremont  California
# 457    Los Angeles, California, United States      Los Angeles  California
#
#            country state_short_name state_y
# 5    United States              NaN     NaN
# 155  United States              NaN     NaN
# 211  United States              NaN     NaN
# 233  United States              NaN     NaN
# 457  United States              NaN     NaN

# %%
df_location_merge.loc[df_location_merge['country'].notnull(), 'state_y'] = df_location_merge['state_x']

# %%
df_location_merge[df_location_merge['country'].notnull()].head(5)
# Out:
#                                      Location             city     state_x  \
# 5    St Clair Shores, Michigan, United States  St Clair Shores    Michigan
# 155       Wilmington, Delaware, United States       Wilmington    Delaware
# 211           Denver, Colorado, United States           Denver    Colorado
# 233        Fremont, California, United States          Fremont  California
# 457    Los Angeles, California, United States      Los Angeles  California
#
#            country state_short_name     state_y
# 5    United States              NaN    Michigan
# 155  United States              NaN    Delaware
# 211  United States              NaN    Colorado
# 233  United States              NaN  California
# 457  United States              NaN  California

# %%
# Drop redundant columns
df_location_merge.drop(columns=['state_x','country','state_short_name'], inplace=True)

# Rename the columns for clarity
df_location_merge.rename(columns={'state_y': 'state'}, inplace=True)

# %%
#drop NA:
df_location_merge.dropna(subset = ['state'])
# Out:
#                                       Location             city  \
# 0                             Little River, SC     Little River
# 1                              Aliso Viejo, CA      Aliso Viejo
# 2                            Daytona Beach, FL    Daytona Beach
# 3                                   Sussex, NJ           Sussex
# 5     St Clair Shores, Michigan, United States  St Clair Shores
# ...                                        ...              ...
# 3866                       University Park, PA  University Park
# 3867                          Marshalltown, IA     Marshalltown
# 3868                        Valley Cottage, NY   Valley Cottage
# 3869                             De Forest, WI        De Forest
# 3870                          North Canton, OH     North Canton
#
#                state
# 0     South Carolina
# 1         California
# 2            Florida
# 3         New Jersey
# 5           Michigan
# ...              ...
# 3866    Pennsylvania
# 3867            Iowa
# 3868        New York
# 3869       Wisconsin
# 3870            Ohio
#
# [3796 rows x 3 columns]

# %% [markdown]
# Now we finally join with the original dataset to get the state:

# %%
jobs_posting = pd.merge(jobs_posting, df_location_merge, left_on='location', right_on='Location', how='left')
#jobs_posting_lcn.dropna(subset = ['state'])
jobs_posting.head(5)
# Out:
#        job_id  company_id                                        title  \
# 0  3757940104    553718.0                        Hearing Care Provider
# 1  3757938018  18213359.0                                         Cook
# 2  3757937095    437225.0  Principal Cloud Security Architect (Remote)
# 3  3757937037     13727.0                Territory Manager - New Haven
# 4  3757937004  10515052.0                          Auto Body Techncian
#
#    max_salary  med_salary  min_salary pay_period formatted_work_type  \
# 0         NaN     5250.00         NaN    MONTHLY           Full-time
# 1         NaN       22.27         NaN     HOURLY           Full-time
# 2    275834.0         NaN    205956.0     YEARLY           Full-time
# 3         NaN         NaN         NaN        NaN           Full-time
# 4         NaN         NaN         NaN        NaN           Full-time
#
#             location  applies  ...  compensation_type     scraped  \
# 0   Little River, SC      NaN  ...        BASE_SALARY  1699138101
# 1    Aliso Viejo, CA      NaN  ...        BASE_SALARY  1699087461
# 2      United States      NaN  ...        BASE_SALARY  1699085346
# 3      United States      NaN  ...                NaN  1699137801
# 4  Daytona Beach, FL      NaN  ...                NaN  1699089473
#
#    new_original_listed_time     new_closed_time     new_listed_time  \
# 0       2023-11-14 22:13:20                 NaT 2023-11-14 22:13:20
# 1       2023-11-14 22:13:20                 NaT 2023-11-14 22:13:20
# 2       2023-11-14 22:13:20                 NaT 2023-11-14 22:13:20
# 3       2023-11-14 22:13:20 2023-11-14 22:13:20 2023-11-14 22:13:20
# 4       2023-11-14 22:13:20                 NaT 2023-11-14 22:13:20
#
#   avg_salary  yearly_avg_salary           Location           city  \
# 0    5250.00           63000.00   Little River, SC   Little River
# 1      22.27           46499.76    Aliso Viejo, CA    Aliso Viejo
# 2  240895.00          240895.00                NaN            NaN
# 3        NaN                NaN                NaN            NaN
# 4        NaN                NaN  Daytona Beach, FL  Daytona Beach
#
#             state
# 0  South Carolina
# 1      California
# 2             NaN
# 3             NaN
# 4         Florida
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Number of job by experience level and company size

# %%
jobs_posting_comp = pd.merge(jobs_posting, df_comp_merged[['company_id', 'Company size']], on='company_id', how='left')

jobs_posting_comp.head(5)
# Out:
#        job_id  company_id                                        title  \
# 0  3757940104    553718.0                        Hearing Care Provider
# 1  3757938018  18213359.0                                         Cook
# 2  3757937095    437225.0  Principal Cloud Security Architect (Remote)
# 3  3757937037     13727.0                Territory Manager - New Haven
# 4  3757937004  10515052.0                          Auto Body Techncian
#
#    max_salary  med_salary  min_salary pay_period formatted_work_type  \
# 0         NaN     5250.00         NaN    MONTHLY           Full-time
# 1         NaN       22.27         NaN     HOURLY           Full-time
# 2    275834.0         NaN    205956.0     YEARLY           Full-time
# 3         NaN         NaN         NaN        NaN           Full-time
# 4         NaN         NaN         NaN        NaN           Full-time
#
#             location  applies  ...     scraped  new_original_listed_time  \
# 0   Little River, SC      NaN  ...  1699138101       2023-11-14 22:13:20
# 1    Aliso Viejo, CA      NaN  ...  1699087461       2023-11-14 22:13:20
# 2      United States      NaN  ...  1699085346       2023-11-14 22:13:20
# 3      United States      NaN  ...  1699137801       2023-11-14 22:13:20
# 4  Daytona Beach, FL      NaN  ...  1699089473       2023-11-14 22:13:20
#
#       new_closed_time     new_listed_time avg_salary yearly_avg_salary  \
# 0                 NaT 2023-11-14 22:13:20    5250.00          63000.00
# 1                 NaT 2023-11-14 22:13:20      22.27          46499.76
# 2                 NaT 2023-11-14 22:13:20  240895.00         240895.00
# 3 2023-11-14 22:13:20 2023-11-14 22:13:20        NaN               NaN
# 4                 NaT 2023-11-14 22:13:20        NaN               NaN
#
#             Location           city           state Company size
# 0   Little River, SC   Little River  South Carolina    1001-5000
# 1    Aliso Viejo, CA    Aliso Viejo      California     501-1000
# 2                NaN            NaN             NaN    1001-5000
# 3                NaN            NaN             NaN    1001-5000
# 4  Daytona Beach, FL  Daytona Beach         Florida  5001-10,000
#
# [5 rows x 36 columns]

# %%
jobs_count = jobs_posting_comp.groupby(['formatted_experience_level', 'Company size']).size()
jobs_count
# Out:
# formatted_experience_level  Company size
# Associate                   10,001 +         584
#                             1001-5000        627
#                             201-500          357
#                             5001-10,000      189
#                             501-1000         241
#                             51-200           398
#                             Under 50         225
# Director                    10,001 +         323
#                             1001-5000        240
#                             201-500          305
#                             5001-10,000      109
#                             501-1000         107
#                             51-200           151
#                             Under 50          71
# Entry level                 10,001 +        3238
#                             1001-5000       1686
#                             201-500          464
#                             5001-10,000     1134
#                             501-1000         670
#                             51-200           578
#                             Under 50         139
# Executive                   10,001 +          52
#                             1001-5000         72
#                             201-500           21
#                             5001-10,000       27
#                             501-1000          30
#                             51-200            38
#                             Under 50          34
# Internship                  10,001 +         162
#                             1001-5000         96
#                             201-500           24
#                             5001-10,000       54
#                             501-1000          34
#                             51-200            10
#                             Under 50           6
# Mid-Senior level            10,001 +        3019
#                             1001-5000       2327
#                             201-500         1128
#                             5001-10,000     1218
#                             501-1000        1125
#                             51-200          1472
#                             Under 50         611
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reset index to have 'Company size' and 'formatted_experience_level' as columns
jobs_count1 = jobs_count.reset_index()

# Pivot the DataFrame to have 'Company size' as rows, 'formatted_experience_level' as columns, and values as job counts
pivot_table = jobs_count1.pivot(index='Company size', columns='formatted_experience_level', values=0)

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, cmap='YlGnBu', annot=True, fmt='g')
plt.title('Number of Jobs by Company Size and Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Company Size')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Mean salary by experience level and company size

# %%
# Group the data by 'Company size' and 'formatted_experience_level', and calculate the mean of 'yearly_avg_salary' for each group
mean_salary = jobs_posting_comp.groupby(['Company size', 'formatted_experience_level'])['yearly_avg_salary'].mean()
# Reset index to have 'Company size' and 'formatted_experience_level' as columns
mean_salary = mean_salary.reset_index()
# Sort by company size
mean_salary = mean_salary.sort_values(by='Company size')
pivot_table = mean_salary.pivot(index='Company size', columns='formatted_experience_level', values='yearly_avg_salary')

# Plot 

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, cmap='YlGnBu', annot=True, fmt='.2f')
plt.title('Mean Salary by Experience Level and Company Size')
plt.xlabel('Experience Level')
plt.ylabel('Company Size')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Salary /Number of job by industry

# %%
comp_industries = pd.read_csv("./data/company_details/company_industries.csv")
jobs_posting_comp = pd.merge(jobs_posting_comp, comp_industries[['company_id', 'industry']], on='company_id', how='left')

# %%
industry_stats = jobs_posting_comp.groupby('industry').agg({'yearly_avg_salary': 'mean', 'job_id': 'count'})
industry_stats = industry_stats.rename(columns={'yearly_avg_salary': 'Mean Salary', 'job_id': 'Number of Jobs'})
industry_stats = industry_stats.dropna()
industry_stats
# Out:
#                                 Mean Salary  Number of Jobs
# industry
# Accounting                     97088.653559             125
# Administration of Justice      80018.147778               9
# Advertising Services           99371.720779             142
# Airlines and Aviation          90574.091250              48
# Airlines/Aviation             111905.611429              14
# ...                                     ...             ...
# Wholesale                      60940.872727              97
# Wholesale Building Materials   69304.919487             121
# Wine & Spirits                 75718.100000               6
# Wireless                       92500.000000               1
# Writing & Editing             114840.000000               1
#
# [196 rows x 2 columns]

# %%
industry_stats_sorted = industry_stats.sort_values(by='Mean Salary', ascending=False) # sort mean
top_10_industries = industry_stats_sorted.head(10) # Select the top 10 industries with the highest mean salary

plt.figure(figsize=(12, 6))
plt.barh(top_10_industries.index, top_10_industries['Mean Salary'], color='skyblue')
plt.xlabel('Mean Salary')
plt.ylabel('Industry')
plt.title('Top 10 Industries with Highest Mean Salary')
plt.gca().invert_yaxis()  # Invert y-axis to display highest salary at the top
plt.show()

# %%
industry_stats_sorted = industry_stats.sort_values(by='Number of Jobs', ascending=False)

# Select the top 10 industries with the highest number of jobs
top_10_jobs = industry_stats_sorted.head(10)

plt.figure(figsize=(12, 6))
plt.barh(top_10_jobs.index, top_10_jobs['Number of Jobs'], color='lightgreen')
plt.xlabel('Number of Jobs')
plt.ylabel('Industry')
plt.title('Top 10 Industries with Most In-Demand Jobs')
plt.gca().invert_yaxis()  # Invert y-axis to display highest demand at the top
plt.show()

# %% [markdown]
# ## Top states with job posting number, average salary

# %%
jobs_posting.columns.tolist()
# Out:
# ['job_id',
#  'company_id',
#  'title',
#  'max_salary',
#  'med_salary',
#  'min_salary',
#  'pay_period',
#  'formatted_work_type',
#  'location',
#  'applies',
#  'original_listed_time',
#  'remote_allowed',
#  'views',
#  'job_posting_url',
#  'application_url',
#  'application_type',
#  'expiry',
#  'closed_time',
#  'formatted_experience_level',
#  'skills_desc',
#  'listed_time',
#  'posting_domain',
#  'sponsored',
#  'work_type',
#  'currency',
#  'compensation_type',
#  'scraped',
#  'new_original_listed_time',
#  'new_closed_time',
#  'new_listed_time',
#  'avg_salary',
#  'yearly_avg_salary',
#  'Location',
#  'city',
#  'state']

# %%
# Top 10 states that post the highest amount of jobs on Linkedln
X_sorted = jobs_posting.groupby('state')['job_id'].count().sort_values(ascending=False).head(10)
X_sorted
# Out:
# state
# California        2667
# Texas             1932
# Florida           1224
# New York          1166
# Illinois           929
# North Carolina     738
# Virginia           722
# Massachusetts      718
# Pennsylvania       702
# Georgia            692
# Name: job_id, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plot the histogram
plt.bar(X_sorted.index, X_sorted.values)
plt.xlabel('State')
plt.ylabel('Job_id Count')
plt.title('Histogram of Number of Job ID by Top 10 States')
plt.xticks(rotation=90)
plt.show()

# %%
X1_sorted = jobs_posting.groupby('state')['yearly_avg_salary'].mean().sort_values(ascending=False).head(10)
X1_sorted
# Out:
# state
# Colorado                556605.541040
# Illinois                456432.953515
# California              283130.654434
# District Of Columbia    118298.812308
# New York                104660.415349
# Massachusetts           104568.639474
# Virginia                 99331.611229
# Washington               95233.463467
# New Hampshire            94666.280645
# South Dakota             94420.986667
# Name: yearly_avg_salary, dtype: float64

# %%
# Plot the histogram
plt.bar(X1_sorted.index, X1_sorted.values)
plt.xlabel('State')
plt.ylabel('AVG yearly salary')
plt.title('Histogram of AVG yearly salary by Top 10 States')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Compare remote vs in person in term of salary, demand

# %%
jobs_posting['remote_allowed'] = jobs_posting['remote_allowed'].replace({1.0: 'Yes', pd.NA:'Other'})
jobs_posting["remote_allowed"].head(5)
# Out:
# 0    NaN
# 1    NaN
# 2    Yes
# 3    Yes
# 4    NaN
# Name: remote_allowed, dtype: object

# %%
# jobs_posting_lcn[jobs_posting_lcn["remote_allowed"]==1].count()
jobs_posting["remote_allowed"].value_counts()
# Out:
# remote_allowed
# Yes    3109
# Name: count, dtype: int64

# %%
# Percentage of job allowed remote working
remote_percentage = (jobs_posting[jobs_posting["remote_allowed"]=="Yes"]["remote_allowed"].count() / len(jobs_posting)) * 100
remote_percentage
# Out:
# 12.919177228339912

# %%
# Percentage of job NOT allowed remote working
not_remote_percentage = 100 - remote_percentage
not_remote_percentage
# Out:
# 87.08082277166008

# %%
# Create labels for pie chart
labels = [f'Remote allowed ({remote_percentage:.2f}%)', f'Other ({not_remote_percentage:.2f}%)']

# Create values for pie chart
sizes = [remote_percentage, not_remote_percentage]

# Plot the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title(f'Percentage of jobs allowed Remote Working')
plt.show()

# %%
# Average yearly salary from jobs that allowed remote working vs Other
X2 = jobs_posting.groupby('remote_allowed')['yearly_avg_salary'].mean()
X2
# Out:
# remote_allowed
# Yes    126969.671669
# Name: yearly_avg_salary, dtype: float64

# %%
plt.bar(X2.index, X2.values)
plt.xlabel('Remote working')
plt.ylabel('AVG yearly salary')
plt.title('Comparison of AVG yearly annual salary between jobs that allowed remote working and Other')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 3.Median Salary by job title across some states in the US

# %%
import seaborn as sns
import matplotlib.pyplot as plt
jobs_posting_nona = jobs_posting.dropna(subset=['state', 'yearly_avg_salary'], how='any')

# Calculate the median salary by job title and by state
med_sal_ts = jobs_posting_nona.groupby(['title', 'state'])['yearly_avg_salary'].median().reset_index()
med_sal_ts
# Out:
#                                                   title        state  \
# 0                   Research Associate II, Pathobiology   California
# 1                                      Account Manager      Nebraska
# 2                               Applications Developer    Washington
# 3              Benefits Customer Service Representative     Delaware
# 4                           Bilingual Clerical Support         Texas
# ...                                                 ...          ...
# 7215                                 eDiscovery Analyst        Texas
# 7216                                eDiscovery Attorney   California
# 7217                        iOS Engineering Lead -A5347   California
# 7218                              iOS Software Engineer   California
# 7219  in-house Contracting Counsel (junior-mid level...  Connecticut
#
#       yearly_avg_salary
# 0               80388.0
# 1               43848.0
# 2              109620.0
# 3               40000.0
# 4               43848.0
# ...                 ...
# 7215            65772.0
# 7216           200000.0
# 7217           145000.0
# 7218           200000.0
# 7219           135000.0
#
# [7220 rows x 3 columns]

# %%
plt.boxplot(med_sal_ts['yearly_avg_salary'])
plt.show()

# %% [markdown]
# There are some outliners that we can observe above so we will identify those outliners and remove it before analysis

# %%
from scipy import stats
data_z_score_sal = stats.zscore(med_sal_ts['yearly_avg_salary'])
med_sal_ts['z_score']=data_z_score_sal
med_sal_ts_filter = med_sal_ts[(med_sal_ts['z_score'] <=3) & (med_sal_ts['z_score'] >= -3)]
plt.boxplot(med_sal_ts_filter['yearly_avg_salary'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There are still some of the value left, however, this is the combination of all job titles and all states so we can drill down by each states and have a better look on those job variations.
#
# In the next code, we narrow down the list of the states to only 10 states that have the highest number of job postings. Then we can see how are the salary ranging in those states

# %%
# Count the occurrences of each state and select the top 10
top_10_states= med_sal_ts_filter['state'].value_counts().head(10).index

# Filter the DataFrame to include only the top 10 job titles
top_10_data = med_sal_ts_filter[med_sal_ts_filter['state'].isin(top_10_states)]

# Create the box plot for the filtered data
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.boxplot(x='state', y='yearly_avg_salary', data=top_10_data)

plt.xticks(rotation=45)
plt.title('Yearly Average Salary for Top 10 States has most of the jobs')
plt.ylabel('Yearly Average Salary')
plt.xlabel('States')

plt.show()

# %% [markdown]
# We now can see some of the ouliner are much highlighted in 3 states: California, Texas and New York.
#
# Redo the process to remove those outliner again, but this time, we will apply outliner checking to each of the states in Top 10 states list.

# %%
# Initialize an empty DataFrame to store the filtered data
filtered_data = pd.DataFrame()

# Calculate Z-scores and filter outliers for each of the top 10 states
for state in top_10_states:
    state_data = top_10_data[top_10_data['state'] == state].copy()
    state_data['z_score'] = stats.zscore(state_data['yearly_avg_salary'])
    state_data_filtered = state_data[(state_data['z_score'] >= -3) & (state_data['z_score'] <= 3)]
    filtered_data = pd.concat([filtered_data, state_data_filtered])

# Plot the box plot for the filtered data again
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.boxplot(x='state', y='yearly_avg_salary', data=filtered_data)

plt.xticks(rotation=45)
plt.title('Yearly Average Salary for Top 10 States (Outliers Removed)')
plt.ylabel('Yearly Average Salary')
plt.xlabel('States')

plt.show()

# %% [markdown]
# Among the states that are postings the most, their salary range are fluctuate slightly different. Florida has the lowest median while big city like New York or California has leading the median salary values.

# %% [markdown]
# ## 4. Competitive company breakdown based on salary, experience and number of applicant

# %%
# Create a series with company_id as index and company_name as values
company_name_mapping = df_comp.set_index('company_id')['name']

# Map company_id in jobs_posting_lcn to company names using the series
jobs_posting['company_name'] = jobs_posting['company_id'].map(company_name_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Create a series with company_id as index and company_name as values
# ----> 2 company_name_mapping = comp.set_index('company_id')['name']
#       4 # Map company_id in jobs_posting_lcn to company names using the series
#       5 jobs_posting['company_name'] = jobs_posting['company_id'].map(company_name_mapping)
#
# NameError: name 'comp' is not defined
